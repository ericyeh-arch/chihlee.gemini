# %%
from google import genai
from dotenv import load_dotenv

load_dotenv()

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的"
)

print(interaction.output_text)
# Out:
# 天空之所以是藍色的，主要與**太陽光**、**地球大氣層**以及**人類眼睛的結構**有關。這可以用一個物理現象來解釋，叫做「**瑞利散射**」（Rayleigh scattering）。
#
# 以下是詳細的步驟拆解：
#
# ### 1. 太陽光其實是「彩虹色」的
# 雖然太陽光看起來是白色的，但它實際上是由紅、橙、黃、綠、藍、靛、紫等各種顏色的光混合而成的。這些光以「波」的形式傳播：
# *   **紅色、黃色光**的波長較**長**。
# *   **藍色、紫色光**的波長較**短**。
#
# ### 2. 大氣層的「阻擋」
# 地球周圍包圍著厚厚的大氣層，裡面充滿了氮氣和氧氣等氣體分子。當太陽光穿過大氣層時，會與這些微小的氣體分子碰撞。
#
# ### 3. 關鍵：瑞利散射
# 根據物理定律，**波長較短的光（藍光、紫光）遇到微小分子時，比波長較長的光（紅光、黃光）更容易被散射（向四面八方彈射開來）**。
# *   紅光和黃光因為波長長，像大波浪一樣，能直接穿透大氣分子直達地面。
# *   藍光和紫光因為波長短，像小波浪一樣，撞到氣體分子後就會不斷被反彈、散射到整個天空中。當我們抬頭看天空時，這些被散射的藍色光線進入我們的眼睛，天空看起來就是藍色的。
#
# ---
#
# ### 常見疑問：為什麼天空不是「紫色」的？
# 紫光的波長比藍光更短，照理說散射得更厲害，天空為什麼不是紫色的？這有兩個原因：
#
# 1.  **太陽光的成分**：太陽放射出的光芒中，藍光的比例本來就比紫光多很多。
# 2.  **人類眼睛的限制**：人類眼睛的視網膜上有三種辨色細胞（紅、綠、藍）。我們的大腦對藍色光和綠色光更為敏感，而對紫色光比較遲鈍。因此，即使天空中有紫光，我們的眼睛也會自動將它與藍光混合，最後在大腦中呈現出美麗的「藍天」。
#
# ### 補充：那為什麼夕陽是紅色的？
# 傍晚或清晨時，太陽角度很低，陽光需要穿過**比中午厚上許多倍**的大氣層才能到達我們的眼睛。
# 在這段漫長的旅程中，藍光在半路上就已經被散射殆盡了，只剩下波長最長、穿透力最強的**紅光、橙光**能成功抵達我們的眼睛，所以夕陽和朝陽看起來就是紅橘色的。
