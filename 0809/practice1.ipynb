# %%
from google import genai

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="Explain how AI works in a few words"
)

print(interaction.output_text)
# Out:
# AI analyzes massive data, finds patterns, and makes predictions.

# %%
from google import genai

client = genai.Client()

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="天空為什麼是藍的?"
)

print(interaction.output_text)
# Out:
# 天空之所以是藍色的，主要是因為一個物理現象，叫做**「瑞利散射」（Rayleigh scattering）**。
#
# 這個過程可以拆解成以下三個好理解的步驟：
#
# ### 1. 太陽光其實是「彩虹色」的
# 雖然太陽光看起來是白色的，但它其實是由紅、橙、黃、綠、藍、靛、紫等所有顏色的光混合而成的。這些光以「波」的形式傳播：
# *   **紅光、橙光**的波長較**長**。
# *   **藍光、紫光**的波長較**短**。
#
# ### 2. 大氣層的「阻擋」與「散射」
# 當太陽光穿過地球的大氣層時，會碰撞到大氣中的氣體分子（主要是氮氣和氧氣）。
# *   波長較長的紅光和黃光穿透力強，能直接穿透這些微小的分子，直達地面。
# *   波長較短的**藍光**，很容易被這些微小的氣體分子阻擋，並**向四面八方散射開來**。當我們抬頭看天空時，這些被散射的藍光便進入了我們的眼睛，所以天空看起來就是藍色的。
#
# ---
#
# ### 常見疑問：既然紫光的波長比藍光更短，為什麼天空不是「紫色」的？
#
# 這是一個非常聰明的問題！紫光的波長確實比藍光更短，散射也更厲害，但天空不是紫色主要有兩個原因：
#
# 1.  **太陽光的成分**：太陽射出的光線中，藍光的比例本來就比紫光多很多。
# 2.  **人類眼睛的構造**：人類眼睛的視網膜上有三種辨色細胞（錐狀細胞），分別對紅、綠、藍色最敏感。我們對紫光的敏感度很低。因此，當散射的藍光、少量的綠光和微量的紫光混合進入眼睛時，我們的大腦會自動將它解讀為**天藍色**。
#
# ---
#
# ### 補充：為什麼傍晚的夕陽是「紅色」的？
# 傍晚時，太陽接近地平線，陽光需要穿過**比中午厚很多**的大氣層才能到達我們的眼睛。
# 在這段漫長的旅程中，波長較短的藍光幾乎在半路就被散射光了，只有波長最長、穿透力最強的**紅光、橙光**能夠成功「抵達終點」進入我們的眼睛，所以夕陽看起來就是美麗的紅橙色。
